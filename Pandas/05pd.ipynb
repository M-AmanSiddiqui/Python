# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sales_data_sample.csv', encoding = "latin")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
#  16  ADDRESSLINE2      302 non-null    object
#  17  CITY              2823 non-null   object
#  18  STATE             1337 non-null   object
#  19  POSTALCODE        2747 non-null   object
#  20  COUNTRY           2823 non-null   object
#  21  TERRITORY         1749 non-null   object
#  22  CONTACTLASTNAME   2823 non-null   object
#  23  CONTACTFIRSTNAME  2823 non-null   object
#  24  DEALSIZE          2823 non-null   object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 551.5+ KB

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# 25%     2203.430000     2.000000     4.000000  2003.00000    68.000000
# 50%     3184.800000     3.000000     8.000000  2004.00000    99.000000
# 75%     4508.000000     4.000000    11.000000  2004.00000   124.000000
# max    14082.800000     4.000000    12.000000  2005.00000   214.000000

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.drop('ADDRESSLINE2', axis=1)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1       5/7/2003 0:00   Shipped       2         5     2003  ...
# 2       7/1/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818   12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820    3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822    5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                  PHONE                   ADDRESSLINE1           CITY STATE  \
# 0           2125557818        897 Long Airport Avenue            NYC    NY
# 1           26.47.1555             59 rue de l'Abbaye          Reims   NaN
# 2     +33 1 46 62 7555  27 rue du Colonel Pierre Avia          Paris   NaN
# 3           6265557265             78934 Hillside Dr.       Pasadena    CA
# 4           6505551386                7734 Strong St.  San Francisco    CA
# ...                ...                            ...            ...   ...
# 2818    (91) 555 94 44             C/ Moralzarzal, 86         Madrid   NaN
# 2819        981-443655                    Torikatu 38           Oulu   NaN
# 2820    (91) 555 94 44             C/ Moralzarzal, 86         Madrid   NaN
# 2821        61.77.6555          1 rue Alsace-Lorraine       Toulouse   NaN
# 2822        6175559555             8616 Spinnaker Dr.         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA       NaN              Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA       NaN           Young            Julie   Medium
# 4           NaN      USA       NaN           Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA       NaN         Yoshido             Juri   Medium
#
# [2823 rows x 24 columns]

# %%
df.drop('STATE', axis=1)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1       5/7/2003 0:00   Shipped       2         5     2003  ...
# 2       7/1/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818   12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820    3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822    5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                  PHONE                   ADDRESSLINE1 ADDRESSLINE2  \
# 0           2125557818        897 Long Airport Avenue          NaN
# 1           26.47.1555             59 rue de l'Abbaye          NaN
# 2     +33 1 46 62 7555  27 rue du Colonel Pierre Avia          NaN
# 3           6265557265             78934 Hillside Dr.          NaN
# 4           6505551386                7734 Strong St.          NaN
# ...                ...                            ...          ...
# 2818    (91) 555 94 44             C/ Moralzarzal, 86          NaN
# 2819        981-443655                    Torikatu 38          NaN
# 2820    (91) 555 94 44             C/ Moralzarzal, 86          NaN
# 2821        61.77.6555          1 rue Alsace-Lorraine          NaN
# 2822        6175559555             8616 Spinnaker Dr.          NaN
#
#                CITY POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME  \
# 0               NYC      10022      USA       NaN              Yu
# 1             Reims      51100   France      EMEA         Henriot
# 2             Paris      75508   France      EMEA        Da Cunha
# 3          Pasadena      90003      USA       NaN           Young
# 4     San Francisco        NaN      USA       NaN           Brown
# ...             ...        ...      ...       ...             ...
# 2818         Madrid      28034    Spain      EMEA          Freyre
# 2819           Oulu      90110  Finland      EMEA       Koskitalo
# 2820         Madrid      28034    Spain      EMEA          Freyre
# 2821       Toulouse      31000   France      EMEA          Roulet
# 2822         Boston      51003      USA       NaN         Yoshido
#
#      CONTACTFIRSTNAME DEALSIZE
# 0                Kwai    Small
# 1                Paul    Small
# 2              Daniel   Medium
# 3               Julie   Medium
# 4               Julie   Medium
# ...               ...      ...
# 2818            Diego    Small
# 2819           Pirkko   Medium
# 2820            Diego   Medium
# 2821          Annette    Small
# 2822             Juri   Medium
#
# [2823 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df['ADDRESSLINE1'].unique()
# Out:
# array(['897 Long Airport Avenue', "59 rue de l'Abbaye",
#        '27 rue du Colonel Pierre Avia', '78934 Hillside Dr.',
#        '7734 Strong St.', '9408 Furth Circle', '184, chausse de Tournai',
#        'Drammen 121, PR 744 Sentrum', '5557 North Pendale Street',
#        '25, rue Lauriston', '636 St Kilda Road', '2678 Kingston Rd.',
#        '7476 Moss Rd.', '25593 South Bay Ln.',
#        '67, rue des Cinquante Otages', '39323 Spinnaker Dr.',
#        'Keskuskatu 45', 'Erling Skakkes gate 78', '7586 Pompton St.',
#        'Geislweg 14', 'Monitor Money Building, 815 Pacific Hwy',
#        '1785 First Street', 'Berkeley Gardens 12  Brewery',
#        'C/ Moralzarzal, 86', 'Berguvsv\x84gen  8', 'C/ Araquil, 67',
#        'Bronz Sok., Bronz Apt. 3/6 Tesvikiye', '5905 Pompton St.',
#        '31 Duncan St. West End', '782 First Street', '2, rue du Commerce',
#        '1900 Oak St.', '3675 Furth Circle', '4658 Baden Av.',
#        '567 North Pendale Street', '2-2-8 Roppongi',
#        'Via Monte Bianco 34', '?kergatan 24', "67, avenue de l'Europe",
#        '5677 Strong St.', '2304 Long Airport Avenue', '7825 Douglas Av.',
#        '201 Miller Street', '43 rue St. Laurent',
#        'Dojima Avanza 4F, 1-6-20 Dojima, Kita-ku', '11328 Douglas Av.',
#        '54, rue Royale', '3758 North Pendale Street', "Vinb'ltet 34",
#        '35 King George', '4575 Hillside Dr.', '1 rue Alsace-Lorraine',
#        '120 Hanover Sq.', 'Rambla de Catalu¤a, 23', '6047 Douglas Av.',
#        '361 Furth Circle', 'Rue Joseph-Bens 532', '23 Tsawassen Blvd.',
#        '8616 Spinnaker Dr.', 'Garden House Crowther Way', 'Torikatu 38',
#        '3086 Ingle Ln.', '265, boulevard Charonne', 'Kirchgasse 6',
#        '6251 Ingle Ln.', 'Village Close - 106 Linden Road Sandown',
#        '15 McCallum Street - NatWest Center #13-03',
#        '12, rue des Bouchers', 'Mehrheimerstr. 369', 'Grenzacherweg 237',
#        'Strada Provinciale 124', '7635 Spinnaker Dr.', 'Lyonerstr. 34',
#        'Software Engineering Center, SEC Oy', '4092 Furth Circle',
#        '25 Maiden Lane', "Merchants House, 27-30 Merchant's Quay",
#        'Fauntleroy Circus', 'Smagsloget 45', '5290 North Pendale Street',
#        '4097 Douglas Av.', 'C/ Romero, 33', '2793 Furth Circle',
#        '24, place Kluber', '8489 Strong St.',
#        'Drammensveien 126 A, PB 744 Sentrum', 'Via Ludovico il Moro 22',
#        '7 Allen Street', '2440 Pompton St.', 'Hansastr. 15',
#        'Boulevard Tirou, 255', '16780 Pompton St.'], dtype=object)

# %%
df['CITY'].unique()
# Out:
# array(['NYC', 'Reims', 'Paris', 'Pasadena', 'San Francisco', 'Burlingame',
#        'Lille', 'Bergen', 'Melbourne', 'Newark', 'Bridgewater', 'Nantes',
#        'Cambridge', 'Helsinki', 'Stavern', 'Allentown', 'Salzburg',
#        'Chatswood', 'New Bedford', 'Liverpool', 'Madrid', 'Lule',
#        'Singapore', 'South Brisbane', 'Philadelphia', 'Lyon', 'Vancouver',
#        'Burbank', 'New Haven', 'Minato-ku', 'Torino', 'Boras',
#        'Versailles', 'San Rafael', 'Nashua', 'Brickhaven', 'North Sydney',
#        'Montreal', 'Osaka', 'White Plains', 'Kobenhavn', 'London',
#        'Toulouse', 'Barcelona', 'Los Angeles', 'San Diego', 'Bruxelles',
#        'Tsawassen', 'Boston', 'Cowes', 'Oulu', 'San Jose', 'Graz',
#        'Makati City', 'Marseille', 'Koln', 'Gensve', 'Reggio Emilia',
#        'Frankfurt', 'Espoo', 'Dublin', 'Manchester', 'Aaarhus',
#        'Glendale', 'Sevilla', 'Brisbane', 'Strasbourg', 'Las Vegas',
#        'Oslo', 'Bergamo', 'Glen Waverly', 'Munich', 'Charleroi'],
#       dtype=object)

# %%
df['COUNTRY'].unique()
# Out:
# array(['USA', 'France', 'Norway', 'Australia', 'Finland', 'Austria', 'UK',
#        'Spain', 'Sweden', 'Singapore', 'Canada', 'Japan', 'Italy',
#        'Denmark', 'Belgium', 'Philippines', 'Germany', 'Switzerland',
#        'Ireland'], dtype=object)

# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.1-py3-none-any.whl.metadata (1.6 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
# Installing collected packages: geographiclib, geopy
#
#    ---------------------------------------- 0/2 [geographiclib]
#    -------------------- ------------------- 1/2 [geopy]
#    -------------------- ------------------- 1/2 [geopy]
#    -------------------- ------------------- 1/2 [geopy]
#    -------------------- ------------------- 1/2 [geopy]
#    -------------------- ------------------- 1/2 [geopy]
#    -------------------- ------------------- 1/2 [geopy]
#    -------------------- ------------------- 1/2 [geopy]
#    ---------------------------------------- 2/2 [geopy]
#
# Successfully installed geographiclib-2.1 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
# Initialize geolocator
geolocator = Nominatim(user_agent="state_finder")

# To avoid being blocked, use a rate limiter (1 request per second is safe)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

def get_state(city, country):
    try:
        location = geocode(f"{city}, {country}")
        raise f'alikhan...................{location}'
        if location and 'state' in location.raw['address']:
            return location.raw['address']['state']
        elif location and 'state_district' in location.raw['address']:
            return location.raw['address']['state_district']
        else:
            return None
    except Exception as e:
        print(f"Error for {city}, {country}: {e}")
        return None

# %%
df.apply(lambda row: get_state(row['CITY'], row['COUNTRY']), axis=1)
# Out:
# Error for NYC, USA: exceptions must derive from BaseException
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Reims, France',), **{}).
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1323, in do_open
#     r = h.getresponse()
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1430, in getresponse
#     response.begin()
#     ~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 719, in readinto
#     return self._sock.recv_into(b)
#            ~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1304, in recv_into
#     return self.read(nbytes, buffer)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1138, in read
#     return self._sslobj.read(len, buffer)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 320, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Reims, France',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1319, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               encode_chunked=req.has_header('Transfer-encoding'))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1338, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1384, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1333, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1093, in _send_output
#     self.send(msg)
#     ~~~~~~~~~^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1037, in send
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1472, in connect
#     super().connect()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1003, in connect
#     self.sock = self._create_connection(
#                 ~~~~~~~~~~~~~~~~~~~~~~~^
#         (self.host,self.port), self.timeout, self.source_address)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 864, in create_connection
#     raise exceptions[0]
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 849, in create_connection
#     sock.connect(sa)
#     ~~~~~~~~~~~~^^^^
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1322, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 316, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter swallowed an error after 2 retries. Called with (*('Reims, France',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1319, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               encode_chunked=req.has_header('Transfer-encoding'))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1338, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1384, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1333, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1093, in _send_output
#     self.send(msg)
#     ~~~~~~~~~^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1037, in send
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1472, in connect
#     super().connect()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1003, in connect
#     self.sock = self._create_connection(
#                 ~~~~~~~~~~~~~~~~~~~~~~~^
#         (self.host,self.port), self.timeout, self.source_address)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 864, in create_connection
#     raise exceptions[0]
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 849, in create_connection
#     sock.connect(sa)
#     ~~~~~~~~~~~~^^^^
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1322, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 316, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# Error for Reims, France: exceptions must derive from BaseException
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1319, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               encode_chunked=req.has_header('Transfer-encoding'))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1338, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1384, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1333, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1093, in _send_output
#     self.send(msg)
#     ~~~~~~~~~^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1037, in send
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1472, in connect
#     super().connect()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1003, in connect
#     self.sock = self._create_connection(
#                 ~~~~~~~~~~~~~~~~~~~~~~~^
#         (self.host,self.port), self.timeout, self.source_address)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 864, in create_connection
#     raise exceptions[0]
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 849, in create_connection
#     sock.connect(sa)
#     ~~~~~~~~~~~~^^^^
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1322, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 316, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1319, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               encode_chunked=req.has_header('Transfer-encoding'))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1338, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1384, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1333, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1093, in _send_output
#     self.send(msg)
#     ~~~~~~~~~^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1037, in send
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1472, in connect
#     super().connect()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1003, in connect
#     self.sock = self._create_connection(
#                 ~~~~~~~~~~~~~~~~~~~~~~~^
#         (self.host,self.port), self.timeout, self.source_address)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 864, in create_connection
#     raise exceptions[0]
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 849, in create_connection
#     sock.connect(sa)
#     ~~~~~~~~~~~~^^^^
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1322, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 316, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# Error for Paris, France: exceptions must derive from BaseException
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Pasadena, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1319, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               encode_chunked=req.has_header('Transfer-encoding'))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1338, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1384, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1333, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1093, in _send_output
#     self.send(msg)
#     ~~~~~~~~~^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1037, in send
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1479, in connect
#     self.sock = self._context.wrap_socket(self.sock,
#                 ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#                                           server_hostname=server_hostname)
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 455, in wrap_socket
#     return self.sslsocket_class._create(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         sock=sock,
#         ^^^^^^^^^^
#     ...<5 lines>...
#         session=session
#         ^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1076, in _create
#     self.do_handshake()
#     ~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1372, in do_handshake
#     self._sslobj.do_handshake()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
# TimeoutError: _ssl.c:1011: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1322, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error _ssl.c:1011: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 316, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Pasadena, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1319, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               encode_chunked=req.has_header('Transfer-encoding'))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1338, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1384, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1333, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1093, in _send_output
#     self.send(msg)
#     ~~~~~~~~~^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1037, in send
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1472, in connect
#     super().connect()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1003, in connect
#     self.sock = self._create_connection(
#                 ~~~~~~~~~~~~~~~~~~~~~~~^
#         (self.host,self.port), self.timeout, self.source_address)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 864, in create_connection
#     raise exceptions[0]
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 849, in create_connection
#     sock.connect(sa)
#     ~~~~~~~~~~~~^^^^
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1322, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 316, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter swallowed an error after 2 retries. Called with (*('Pasadena, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1319, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               encode_chunked=req.has_header('Transfer-encoding'))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1338, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1384, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1333, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1093, in _send_output
#     self.send(msg)
#     ~~~~~~~~~^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1037, in send
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1472, in connect
#     super().connect()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1003, in connect
#     self.sock = self._create_connection(
#                 ~~~~~~~~~~~~~~~~~~~~~~~^
#         (self.host,self.port), self.timeout, self.source_address)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 864, in create_connection
#     raise exceptions[0]
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 849, in create_connection
#     sock.connect(sa)
#     ~~~~~~~~~~~~^^^^
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1322, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 316, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# Error for Pasadena, USA: exceptions must derive from BaseException
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('San Francisco, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1319, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               encode_chunked=req.has_header('Transfer-encoding'))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1338, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1384, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1333, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1093, in _send_output
#     self.send(msg)
#     ~~~~~~~~~^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1037, in send
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1472, in connect
#     super().connect()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1003, in connect
#     self.sock = self._create_connection(
#                 ~~~~~~~~~~~~~~~~~~~~~~~^
#         (self.host,self.port), self.timeout, self.source_address)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 864, in create_connection
#     raise exceptions[0]
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 849, in create_connection
#     sock.connect(sa)
#     ~~~~~~~~~~~~^^^^
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1322, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 316, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('San Francisco, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1319, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               encode_chunked=req.has_header('Transfer-encoding'))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1338, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1384, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1333, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1093, in _send_output
#     self.send(msg)
#     ~~~~~~~~~^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1037, in send
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1472, in connect
#     super().connect()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1003, in connect
#     self.sock = self._create_connection(
#                 ~~~~~~~~~~~~~~~~~~~~~~~^
#         (self.host,self.port), self.timeout, self.source_address)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 864, in create_connection
#     raise exceptions[0]
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 849, in create_connection
#     sock.connect(sa)
#     ~~~~~~~~~~~~^^^^
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1322, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 316, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# Error for San Francisco, USA: exceptions must derive from BaseException
# Error for Burlingame, USA: exceptions must derive from BaseException
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Lille, France',), **{}).
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1323, in do_open
#     r = h.getresponse()
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1430, in getresponse
#     response.begin()
#     ~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 719, in readinto
#     return self._sock.recv_into(b)
#            ~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1304, in recv_into
#     return self.read(nbytes, buffer)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1138, in read
#     return self._sslobj.read(len, buffer)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 320, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# Error for Lille, France: exceptions must derive from BaseException
# Error for Bergen, Norway: exceptions must derive from BaseException
# Error for San Francisco, USA: exceptions must derive from BaseException
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1319, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               encode_chunked=req.has_header('Transfer-encoding'))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1338, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1384, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1333, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1093, in _send_output
#     self.send(msg)
#     ~~~~~~~~~^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1037, in send
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1479, in connect
#     self.sock = self._context.wrap_socket(self.sock,
#                 ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#                                           server_hostname=server_hostname)
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 455, in wrap_socket
#     return self.sslsocket_class._create(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         sock=sock,
#         ^^^^^^^^^^
#     ...<5 lines>...
#         session=session
#         ^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1076, in _create
#     self.do_handshake()
#     ~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1372, in do_handshake
#     self._sslobj.do_handshake()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
# TimeoutError: _ssl.c:1011: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1322, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error _ssl.c:1011: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 316, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# Error for Paris, France: exceptions must derive from BaseException
# Error for Melbourne, Australia: exceptions must derive from BaseException
# Error for NYC, USA: exceptions must derive from BaseException
# Error for Newark, USA: exceptions must derive from BaseException
# Error for Bridgewater, USA: exceptions must derive from BaseException
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Nantes, France',), **{}).
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1323, in do_open
#     r = h.getresponse()
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1430, in getresponse
#     response.begin()
#     ~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 719, in readinto
#     return self._sock.recv_into(b)
#            ~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1304, in recv_into
#     return self.read(nbytes, buffer)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1138, in read
#     return self._sslobj.read(len, buffer)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 320, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Nantes, France',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1319, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               encode_chunked=req.has_header('Transfer-encoding'))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1338, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1384, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1333, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1093, in _send_output
#     self.send(msg)
#     ~~~~~~~~~^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1037, in send
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1472, in connect
#     super().connect()
#     ~~~~~~~~~~~~~~~^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 1003, in connect
#     self.sock = self._create_connection(
#                 ~~~~~~~~~~~~~~~~~~~~~~~^
#         (self.host,self.port), self.timeout, self.source_address)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 864, in create_connection
#     raise exceptions[0]
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 849, in create_connection
#     sock.connect(sa)
#     ~~~~~~~~~~~~^^^^
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 298, in get_text
#     page = self.urlopen(req, timeout=timeout)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 489, in open
#     response = self._open(req, data)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 506, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#                               '_open', req)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 466, in _call_chain
#     result = func(*args)
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1367, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         context=self._context)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sc\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py", line 1322, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 287, in get_json
#     text = self.get_text(url, timeout=timeout, headers=headers)
#   File "e:\Desktop\Python\Practice\.venv\Lib\site-packages\geopy\adapters.py", line 316, in get_text
#     raise GeocoderTimedOut("Service timed out")
# geopy.exc.GeocoderTimedOut: Service timed out

# %%
df.drop('STATE', axis=1, inplace=True)

# %%
len(df[df['CITY'].str.contains('Paris')].index)
