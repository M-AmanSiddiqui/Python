# %%
import matplotlib.pyplot as plt

# Data for the bar chart
categories = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
values = [320, 450, 500, 480, 600]
colors = ['skyblue', 'lightgreen', 'salmon', 'gold', 'orchid']

# %%
fig = 'colored_bar_chart.png'
plt.title('Monthly Sales Data')
plt.xlabel('Month')
plt.ylabel('Sales (s)')
plt.bar(categories, values, color=colors)
plt.savefig(fig) 
print(f'Colored bar chart saved as {fig}')
plt.show()
# Out:
# Colored bar chart saved as colored_bar_chart.png

# %%
import matplotlib.pyplot as plt

# Data for the bar chart
categories = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
values = [320, 450, 500, 480, 600]
colors = ['skyblue']

# %%
fig = 'bar_chart_with_legend.png'
plt.title('Monthly Sales Data')
plt.xlabel('Month')
plt.ylabel('Sales (s)')
plt.bar(categories, values, color=colors, label='This Year Sales')
plt.legend(loc='upper left')
plt.savefig(fig) 
print(f'Bar chart with legend saved as  {fig}')
plt.show()
# Out:
# Bar chart with legend saved as  bar_chart_with_legend.png

# %% [markdown]
# # Lab 2

# %%
import numpy as np

# Data for plotting
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])

# %%
fig = 'scatter_plot.png'
plt.scatter(x, y)
plt.savefig(fig)
plt.show()
print(f'Scatter plot saved to {fig}')
# Out:
# Scatter plot saved to scatter_plot.png

# %%
import numpy as np

# Data for plotting
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
sizes = np.array([20, 50, 100, 200, 500, 1000, 60, 90, 10, 300, 600, 800, 75])

# %%
fig = 'scatter_plot_sizes.png'
plt.scatter(x, y, s=sizes)
plt.savefig(fig)
plt.show()
print(f'Scatter plot saved to {fig}')
# Out:
# Scatter plot saved to scatter_plot_sizes.png

# %%
import numpy as np

# Data for plotting
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
sizes = np.array([20, 50, 100, 200, 500, 1000, 60, 90, 10, 300, 600, 800, 75])
colors = np.array(["red", "green", "blue", "yellow", "pink", "black", "orange", "purple", "beige", "brown", "gray", "cyan", "magenta"])

# %%
fig = 'scatter_plot_colors.png'
plt.scatter(x, y, s=sizes, c=colors)
plt.savefig(fig)
plt.show()
print(f'Scatter plot saved to {fig}')
# Out:
# Scatter plot saved to scatter_plot_colors.png

# %%
import numpy as np

# Data for plotting
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
sizes = np.array([20, 50, 100, 200, 500, 1000, 60, 90, 10, 300, 600, 800, 75])
colors = np.array(["red", "green", "blue", "yellow", "pink", "black", "orange", "purple", "beige", "brown", "gray", "cyan", "magenta"])

# %%
fig = 'scatter_plot_grid.png'
plt.scatter(x, y, s=sizes, c=colors)
plt.grid(True)
plt.savefig(fig)
plt.show()
print(f'Scatter plot saved to {fig}')
# Out:
# Scatter plot saved to scatter_plot_grid.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['A', 'B', 'C', 'D']
values1 = [10, 15, 7, 20]
values2 = [12, 18, 6, 15]

# %%
x = np.arange(len(categories))
x
# Out:
# array([0, 1, 2, 3])

# %%
width = 0.35

fig, ax = plt.subplots()
print(fig, ax)
# Out:
# Figure(640x480) AxesSubplot(0.125,0.11;0.775x0.77)

# %%
x - width/2,
# Out:
# (array([-0.175,  0.825,  1.825,  2.825]),)

# %%
bars1 = ax.bar(x, values1, label='Group 1')
bars2 = ax.bar(x, values2, label='Group 2')
print(bars1)
print(bars2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 bars1 = ax.bar(x, values1, label='Group 1')
#       2 bars2 = ax.bar(x, values2, label='Group 2')
#       3 print(bars1)
#
# NameError: name 'ax' is not defined

# %%
ax.set_xlabel('Categories')
ax.set_ylabel('Values')
ax.set_title('Grouped Bar Plot')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 ax.set_xlabel('Categories')
#       2 ax.set_ylabel('Values')
#       3 ax.set_title('Grouped Bar Plot')
#
# NameError: name 'ax' is not defined

# %%
x = np.arange(len(categories)) - width/2
y = np.arange(len(categories)) + width/2
print(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 x = np.arange(len(categories)) - width/2
#       2 y = np.arange(len(categories)) + width/2
#       3 print(x, y)
#
# NameError: name 'width' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['Ali', 'Rahim', 'Hassam', 'Faizan']
values1 = [10, 15, 7, 20]
values2 = [12, 18, 6, 15]
values3 = [8, 10, 12, 9]

# %%
x = np.arange(len(categories))
x
# Out:
# array([0, 1, 2, 3])

# %%
x = np.arange(len(categories))
width = 0.2

fig, ax = plt.subplots()

bars1 = ax.bar(x - width, values1, width, label='Group 1')
bars2 = ax.bar(x , values2, width, label='Group 2')
bars2 = ax.bar(x + width, values3, width, label='Group 2')

ax.set_xlabel('Categories')
ax.set_ylabel('Values')
ax.set_title('Grouped Bar Plot')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.show()
